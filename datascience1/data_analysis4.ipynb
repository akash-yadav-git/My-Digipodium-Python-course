# %%
import pandas as pd
import numpy as np
import folium

# %%
df_incidents=pd.read_csv('incidents.csv',parse_dates=['Date'],dayfirst=True)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_42924\1847892519.py:1: DtypeWarning: Columns (1,2,3,5,6,7,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_incidents=pd.read_csv('incidents.csv',parse_dates=['Date'],dayfirst=True)

# %%
df_incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IncidntNum  64168 non-null  float64
#  1   Category    64168 non-null  object
#  2   Descript    64168 non-null  object
#  3   DayOfWeek   64168 non-null  object
#  4   Date        64168 non-null  datetime64[ns]
#  5   Time        64168 non-null  object
#  6   PdDistrict  64168 non-null  object
#  7   Resolution  64168 non-null  object
#  8   Address     64168 non-null  object
#  9   X           64168 non-null  float64
#  10  Y           64168 non-null  float64
#  11  Location    64168 non-null  object
#  12  PdId        64168 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 14.9+ MB

# %%
df_incidents.dropna(inplace=True)

# %%
df_incidents.head()
# Out:
#     IncidntNum      Category                                        Descript  \
# 0  120058272.0   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1  120058272.0   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2  141059263.0      WARRANTS                                  WARRANT ARREST
# 3  160013662.0  NON-CRIMINAL                                   LOST PROPERTY
# 4  160002740.0  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek       Date   Time  PdDistrict      Resolution  \
# 0    Friday 2016-01-29  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday 2016-01-29  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday 2016-04-25  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday 2016-05-01  23:50  TENDERLOIN            NONE
# 4    Friday 2016-01-01  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
# 2   KEITH ST / SHAFTER AV -122.388856  37.729981
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
#
#                                 Location          PdId
# 0   (37.775420706711, -122.403404791479)  1.200580e+13
# 1   (37.775420706711, -122.403404791479)  1.200580e+13
# 2  (37.7299809672996, -122.388856204292)  1.410590e+13
# 3  (37.7857883766888, -122.412970537591)  1.600140e+13
# 4  (37.7650501214668, -122.419671780296)  1.600030e+13

# %%
lat,lng=37.77, -122.42 #san francisco

# %%
map=folium.Map([lat,lng],zoom_start=11)
crimes=folium.map.FeatureGroup()
data=df_incidents[:1000]#limit
for lat,lng in zip(data.Y, data.X):
    crimes.add_child(
        folium.CircleMarker(
            [lat,lng],
            radius=3,
            color='green',
            fill=True,
            fill_color='blue',
            fill_opacity=.5
        )
    )
    map.add_child(crimes)

# %%
map=folium.Map([lat,lng],zoom_start=11)
crimes=folium.map.FeatureGroup()
data=df_incidents[:100]
latitudes=list(data.Y)
longitudes=list(data.X)
label=list(data.Category)
for lat,lng,label in zip(latitudes,longitudes,label):
    folium.Marker((lat,lng), popup=label).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_990bfbd9aa853fb92041849bef8e652d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_990bfbd9aa853fb92041849bef8e652d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_990bfbd9aa853fb92041849bef8e652d = L.map(
#                 &quot;map_990bfbd9aa853fb92041849bef8e652d&quot;,
#                 {
#                     center: [37.72926264, -122.3824755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccc23fda967a4b2ee7c942a4efc69408 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#             var marker_047c7d3517abc8acbc6bf12b76b3ab31 = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_50a12e1a57df21863283922d1be3a664 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ba5e1549ddb6fd19e7c0e0cd17175eb = $(`&lt;div id=&quot;html_3ba5e1549ddb6fd19e7c0e0cd17175eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_50a12e1a57df21863283922d1be3a664.setContent(html_3ba5e1549ddb6fd19e7c0e0cd17175eb);
#
#
#         marker_047c7d3517abc8acbc6bf12b76b3ab31.bindPopup(popup_50a12e1a57df21863283922d1be3a664)
#         ;
#
#
#
#
#             var marker_6ed06355f0357b773db95d5ff8e06984 = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_1b782523aa20b6566b5b739990e1b1b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_34eed210ce8fe5d44d31c115617e3fbc = $(`&lt;div id=&quot;html_34eed210ce8fe5d44d31c115617e3fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_1b782523aa20b6566b5b739990e1b1b7.setContent(html_34eed210ce8fe5d44d31c115617e3fbc);
#
#
#         marker_6ed06355f0357b773db95d5ff8e06984.bindPopup(popup_1b782523aa20b6566b5b739990e1b1b7)
#         ;
#
#
#
#
#             var marker_9c16bdfdc2afff533d3af8fe3bbba7b9 = L.marker(
#                 [37.72998097, -122.3888562],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_6a95bd185967881804f0f7d86f31b3df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_933155e80f59d6451370f99286f72dd4 = $(`&lt;div id=&quot;html_933155e80f59d6451370f99286f72dd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_6a95bd185967881804f0f7d86f31b3df.setContent(html_933155e80f59d6451370f99286f72dd4);
#
#
#         marker_9c16bdfdc2afff533d3af8fe3bbba7b9.bindPopup(popup_6a95bd185967881804f0f7d86f31b3df)
#         ;
#
#
#
#
#             var marker_09e74bc884f463d48da93740efe6d6ee = L.marker(
#                 [37.78578838, -122.4129705],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_8583103886add811563ab07f25814a65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_100f4e52a602dd19db64cf227680c7ba = $(`&lt;div id=&quot;html_100f4e52a602dd19db64cf227680c7ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_8583103886add811563ab07f25814a65.setContent(html_100f4e52a602dd19db64cf227680c7ba);
#
#
#         marker_09e74bc884f463d48da93740efe6d6ee.bindPopup(popup_8583103886add811563ab07f25814a65)
#         ;
#
#
#
#
#             var marker_b45de6a42ff38df28292c103bfa83468 = L.marker(
#                 [37.76505012, -122.4196718],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_d13697b63427649a43986d1247a87bfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6e8ad98d8bc7a82cf1cc3c445a96dc3f = $(`&lt;div id=&quot;html_6e8ad98d8bc7a82cf1cc3c445a96dc3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_d13697b63427649a43986d1247a87bfc.setContent(html_6e8ad98d8bc7a82cf1cc3c445a96dc3f);
#
#
#         marker_b45de6a42ff38df28292c103bfa83468.bindPopup(popup_d13697b63427649a43986d1247a87bfc)
#         ;
#
#
#
#
#             var marker_976fe4a88c9bf536961fe17094c1f5f2 = L.marker(
#                 [37.78801856, -122.4260772],
#                 {}
#             ).addTo(map_990bfbd9aa853fb92041849bef8e652d);
#
#
#         var popup_166e41595b1bc0b04109a78b8fcaefd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b7ce1b8cf09abaa2dcb9ff5b20048743 = $(`&lt;div id=&quot;html_b7ce1b8cf09ab

# %%
map=folium.Map([lat,lng],zoom_start=11)
crimes=folium.map.FeatureGroup()
data=df_incidents[:100]
latitudes=list(data.Y)
longitudes=list(data.X)
label=list(data.Category)
incidents=plugins.MarkerCluster().add_to(map)
for lat,lng,label in zip(latitudes,longitudes,label):
    folium.Marker((lat,lng), popup=label).add_to(incidents)
map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Akanksha\Documents\Python\datascience1\data_analysis4.ipynb Cell 9' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Python/datascience1/data_analysis4.ipynb#ch0000008?line=4'>5</a> longitudes=list(data.X)
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Python/datascience1/data_analysis4.ipynb#ch0000008?line=5'>6</a> label=list(data.Category)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Python/datascience1/data_analysis4.ipynb#ch0000008?line=6'>7</a> incidents=plugins.MarkerCluster().add_to(map)
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Python/datascience1/data_analysis4.ipynb#ch0000008?line=7'>8</a> for lat,lng,label in zip(latitudes,longitudes,label):
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Python/datascience1/data_analysis4.ipynb#ch0000008?line=8'>9</a>     folium.Marker((lat,lng), popup=label).add_to(incidents)
#
# NameError: name 'plugins' is not defined
