# %%
import pandas as pd

# %%
df=pd.read_csv('flipkart_laptop_Aug_22.csv')

# %%
df
# Out:
#      Unnamed: 0                                              title    price  \
# 0             0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490
# 1             1  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990
# 2             2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490
# 3             3  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490
# 4             4  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990
# ..          ...                                                ...      ...
# 201         201  HP Pavilion Ryzen 5 Hexa Core 5625U - (8 GB/51...  ₹56,990
# 202         202  acer Intel EVO Swift 3 Core i5 11th Gen - (8 G...  ₹61,090
# 203         203  Lenovo IdeaPad Core i3 10th Gen - (4 GB/256 GB...  ₹35,990
# 204         204  Infinix X1 Slim Series Core i3 10th Gen - (8 G...  ₹29,990
# 205         205  ASUS TUF Gaming F17 (2022) Core i5 12th Gen - ...  ₹94,990
#
#                               rr  \
# ...

# %%
df=pd.read_csv('flipkart_laptop_Aug_22.csv',usecols=['title','price','rr'],nrows=100)
df
# Out:
#                                                 title    price  \
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490
# 1   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990
# ..                                                ...      ...
# 95  HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/...  ₹37,990
# 96  Lenovo Thinkpad Ryzen 5 Hexa Core 5600U - (8 G...  ₹56,990
# 97  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  ₹41,390
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990
#
#                              rr
# 0   1,253 Ratings & 125 Reviews
# 1      551 Ratings & 67 Reviews
# 2   2,234 Ratings & 258 Reviews
# 3   3,472 Ratings & 368 Reviews
# 4      290 Ratings & 29 Reviews
# ...

# %%
df.head(4)
# Out:
#                                                title    price  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490
# 1  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490
# 3  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490
#
#                             rr
# 0  1,253 Ratings & 125 Reviews
# 1     551 Ratings & 67 Reviews
# 2  2,234 Ratings & 258 Reviews
# 3  3,472 Ratings & 368 Reviews

# %%
df.tail(3)
# Out:
#                                                 title    price  \
# 97  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  ₹41,390
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990
#
#                           rr
# 97     4 Ratings & 0 Reviews
# 98    15 Ratings & 1 Reviews
# 99  198 Ratings & 37 Reviews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   100 non-null    object
#  1   price   100 non-null    object
#  2   rr      100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#                                                     title    price  \
# count                                                 100      100
# unique                                                 90       70
# top     ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core 68...  ₹39,490
# freq                                                    2        3
#
#                            rr
# count                     100
# unique                     86
# top     4 Ratings & 0 Reviews
# freq                        3

# %% [markdown]
# data manipulation

# %%
df.rename({'details':'configuration','title':'product_name'},axis=1,inplace=True)

# %%
df['website']='flipkart'

# %%
df
# Out:
#                                          product_name    price  \
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490
# 1   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990
# ..                                                ...      ...
# 95  HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/...  ₹37,990
# 96  Lenovo Thinkpad Ryzen 5 Hexa Core 5600U - (8 G...  ₹56,990
# 97  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  ₹41,390
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990
#
#                              rr   website
# 0   1,253 Ratings & 125 Reviews  flipkart
# 1      551 Ratings & 67 Reviews  flipkart
# 2   2,234 Ratings & 258 Reviews  flipkart
# ...

# %%
df.drop(columns=['rr'],inplace=True)

# %%
df
# Out:
#                                          product_name    price   website
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490  flipkart
# 1   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990  flipkart
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490  flipkart
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490  flipkart
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990  flipkart
# ..                                                ...      ...       ...
# 95  HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/...  ₹37,990  flipkart
# 96  Lenovo Thinkpad Ryzen 5 Hexa Core 5600U - (8 G...  ₹56,990  flipkart
# 97  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  ₹41,390  flipkart
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490  flipkart
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990  flipkart
#
# [100 rows x 3 columns]

# %%
#task 1: creat a column brand and store the brand name in it taken from the
#  first column
df['brand']=df['product_name'].apply(lambda x:x.split()[0])

# %%
df
# Out:
#                                          product_name    price   website  \
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490  flipkart
# 1   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990  flipkart
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490  flipkart
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490  flipkart
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990  flipkart
# ..                                                ...      ...       ...
# 95  HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/...  ₹37,990  flipkart
# 96  Lenovo Thinkpad Ryzen 5 Hexa Core 5600U - (8 G...  ₹56,990  flipkart
# 97  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  ₹41,390  flipkart
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490  flipkart
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990  flipkart
#
#      brand
# 0   Lenovo
# 1   Lenovo
# 2     ASUS
# 3   Lenovo
# 4       HP
# ..     ...
# ...

# %%
df['link']=df['link'].apply(lambda x:'https://www.flipkart.com'+x)

# %%
df['brand'].value_counts()
# Out:
# ASUS         37
# HP           18
# Lenovo       16
# DELL         11
# acer          7
# MSI           6
# RedmiBook     3
# Infinix       1
# APPLE         1
# Name: brand, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  100 non-null    object
#  1   price         100 non-null    object
#  2   website       100 non-null    object
#  3   brand         100 non-null    object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %%
df['brand'].value_counts().plot(kind='bar')# pip install matplotlib
# Out:
# <AxesSubplot:>

# %%
df.drop_duplicates(subset=['product_name'],inplace=True)

# %%
df
# Out:
#                                          product_name    price   website  \
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹39,490  flipkart
# 1   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹46,990  flipkart
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,490  flipkart
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹33,490  flipkart
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹40,990  flipkart
# ..                                                ...      ...       ...
# 93  ASUS VivoBook K15 OLED (2022) Core i3 11th Gen...  ₹45,990  flipkart
# 95  HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/...  ₹37,990  flipkart
# 96  Lenovo Thinkpad Ryzen 5 Hexa Core 5600U - (8 G...  ₹56,990  flipkart
# 98  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...  ₹72,490  flipkart
# 99  MSI Katana GF66 Core i5 11th Gen - (16 GB/512 ...  ₹73,990  flipkart
#
#      brand
# 0   Lenovo
# 1   Lenovo
# 2     ASUS
# 3   Lenovo
# 4       HP
# ..     ...
# ...

# %%
df.shape
# Out:
# (90, 4)

# %%
df.groupby('brand')['price'].max()
# Out:
# brand
# APPLE        ₹1,29,990
# ASUS           ₹76,990
# DELL           ₹75,990
# HP             ₹67,990
# Infinix        ₹24,990
# Lenovo         ₹72,990
# MSI            ₹87,990
# RedmiBook      ₹46,990
# acer           ₹54,990
# Name: price, dtype: object

# %%
df.groupby('brand')['price'].min()
# Out:
# brand
# APPLE        ₹1,29,990
# ASUS         ₹1,05,990
# DELL           ₹33,090
# HP             ₹29,785
# Infinix        ₹24,990
# Lenovo         ₹27,999
# MSI          ₹1,09,990
# RedmiBook      ₹34,990
# acer           ₹29,990
# Name: price, dtype: object
